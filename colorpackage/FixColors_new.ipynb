# %%
# %run /Users/granthussey/Lab/Schluter/ColorPackage/colors

# %%
import pandas as pd
import random

# %%
tax = pd.read_csv('/Users/granthussey/Lab/Schluter/ColorPackage/test_tax.csv', index_col='ASV')
tax
# Out:
#             Kingdom          Phylum                Class               Order  \
# ASV
# ASV_1      Bacteria      Firmicutes              Bacilli     Lactobacillales
# ASV_10     Bacteria      Firmicutes           Clostridia       Clostridiales
# ASV_100    Bacteria   Bacteroidetes          Bacteroidia       Bacteroidales
# ASV_1000   Bacteria      Firmicutes           Clostridia       Clostridiales
# ASV_10000  Bacteria      Firmicutes           Clostridia       Clostridiales
# ...             ...             ...                  ...                 ...
# ASV_9992   Bacteria      Firmicutes     Erysipelotrichia  Erysipelotrichales
# ASV_9994   Bacteria      Firmicutes           Clostridia       Clostridiales
# ASV_9996   Bacteria      Firmicutes           Clostridia       Clostridiales
# ASV_9997   Bacteria      Firmicutes           Clostridia       Clostridiales
# ASV_9998   Bacteria  Proteobacteria  Gammaproteobacteria   Enterobacteriales
#
# ...

# %%
test = tax.loc[pd.Index(random.sample(list(tax.index), 50))]

match_colors(test)
# Out:
#                           Family   Kingdom          Phylum  \
# index
# ASV_4085        Clostridiaceae 1  Bacteria      Firmicutes
# ASV_934          Enterococcaceae  Bacteria      Firmicutes
# ASV_62614    Erysipelotrichaceae  Bacteria      Firmicutes
# ASV_3917     Erysipelotrichaceae  Bacteria      Firmicutes
# ASV_787      Erysipelotrichaceae  Bacteria      Firmicutes
# ASV_3651             Family XIII  Bacteria      Firmicutes
# ASV_56999        Lachnospiraceae  Bacteria      Firmicutes
# ASV_56642        Lachnospiraceae  Bacteria      Firmicutes
# ASV_5464         Lachnospiraceae  Bacteria      Firmicutes
# ASV_763          Lachnospiraceae  Bacteria      Firmicutes
# ASV_21143        Lachnospiraceae  Bacteria      Firmicutes
# ASV_12794        Lachnospiraceae  Bacteria      Firmicutes
# ASV_58150        Lachnospiraceae  Bacteria      Firmicutes
# ASV_1980         Lachnospiraceae  Bacteria      Firmicutes
# ASV_64698        Lachnospiraceae  Bacteria      Firmicutes
# ...
